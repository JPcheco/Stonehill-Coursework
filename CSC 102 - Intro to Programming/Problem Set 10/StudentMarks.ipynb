# %%
#Jacob Pacheco & Lorelie Murphy
#CSC 102-A Intro To Programming
#Problem Set 10: Grades

# The attached file details students performance by number of courses, time spend studying and grades.

# In this assignment you are to: 

# Find:

# the average mark by number of courses (number)
# the highest amount of time spend studying by number of courses (number)
# the lowest amount of time spend studying by number of courses (number)
# the highest grade by number of courses (number)
# the lowest grade by number of courses (number)
# Produce at least 3 graphs that visually illustrate relationships in the data.  

# Write a 500 word essay detailing your analysis and conclusions re: the data.

import csv
import matplotlib.pyplot as plt
student = []

# number_courses = 0
# time_study = 1
# Marks = 2

# read in CSV 
with open('Student_Marks.csv') as file_object:
    reader = csv.reader(file_object)
    header_row = next(reader)
    for row in reader:
        student.append(list(map(float, row)))
file_object.close()
print(student)

# the total number of hours spent studying (number)
totalHours = 0
for row in student:
 totalHours += float(row[1])
print("Total number of hours spent studying:",totalHours)

# the average amount of time spent studying by number of courses (number)  
# the average mark by number of courses (number)
# the highest amount of time spend studying by number of courses (number)
# the lowest amount of time spend studying by number of courses (number)
# the highest grade by number of courses (number)
# the lowest grade by number of courses (number)

threeC, fourC, fiveC, sixC, sevenC, eightC = 0, 0, 0, 0, 0, 0
threeCAVG, fourCAVG, fiveCAVG, sixCAVG, sevenCAVG, eightCAVG = 0, 0, 0, 0, 0, 0
threeTIME, fourTIME, fiveTIME, sixTIME, sevenTIME, eightTIME = 0, 0, 0, 0, 0, 0

threeMrkAvg, fourMrkAvg, fiveMrkAvg, sixMrkAvg, sevenMrkAvg, eightMrkAvg = 0, 0, 0, 0, 0, 0
AVGthree, AVGFour, AVGFive, AVGSix, AVGSeven, AVGeight = 0, 0, 0, 0, 0, 0

HighTimeThree, HighTimeFour, HighTimeFive, HighTimeSix, HighTimeSeven, HighTimeEight = 0, 0, 0, 0, 0, 0
LowTimeThree, LowTimeFour, LowTimeFive, LowTimeSix, LowTimeSeven, LowTimeEight = 0, 0, 0, 0, 0, 0
lowCheck3, lowCheck4, lowCheck5, lowCheck6, lowCheck7, lowCheck8 = 0, 0, 0, 0, 0, 0

HighMarkThree, HighMarkFour, HighMarkFive, HighMarkSix, HighMarkSeven, HighMarkEight = 0, 0, 0, 0, 0, 0
LowMarkThree, LowMarkFour, LowMarkFive, LowMarkSix, LowMarkSeven, LowMarkEight = 0, 0, 0, 0, 0, 0
low3, low4, low5, low6, low7, low8 = 0, 0, 0, 0, 0, 0




for s in student:
    if(s[0] == 3):
        threeCAVG += s[1] #for the average time
        threeMrkAvg +=s[2]#for the average marks
        threeC += 1
        if(s[1] > HighTimeThree):
            HighTimeThree = s[1]
        if(lowCheck3 == 0):
            lowCheck3 +=1;
            LowTimeThree = s[1]
        if(s[1] < LowTimeThree):
            LowTimeThree = s[1]

        if(s[2] > HighMarkThree):
            HighMarkThree = s[2]
        if(low3 == 0):
            low3 +=1;
            LowMarkThree = s[2]
        if(s[2] < LowMarkThree):
            LowMarkThree = s[2]

    elif(s[0] == 4):
        fourCAVG += s[1]
        fourMrkAvg += s[2]
        fourC += 1
        if(s[1] > HighTimeFour):
            HighTimeFour = s[1]
        if(lowCheck4 == 0):
            lowCheck4 +=1;
            LowTimeFour = s[1]
        if(s[1] < LowTimeFour):
            LowTimeFour = s[1]

        if(s[2] > HighMarkFour):
            HighMarkFour = s[2]
        if(low4 == 0):
            low4 +=1;
            LowMarkFour = s[2]
        if(s[2] < LowMarkFour):
            LowMarkFour = s[2]


    elif(s[0] == 5):
        fiveCAVG += s[1]
        fiveMrkAvg += s[2]
        fiveC += 1
        if(s[1] > HighTimeFive):
            HighTimeFive = s[1]
        if(lowCheck5 == 0):
            lowCheck5 +=1;
            LowTimeFive = s[1]
        if(s[1] < LowTimeFive):
            LowTimeFive = s[1]
        if(s[2] > HighMarkFive):
            HighMarkFive = s[2]
        if(low5 == 0):
            low5 +=1;
            LowMarkFive = s[2]
        if(s[2] < LowMarkFive):
            LowMarkFive = s[2]
    elif(s[0] == 6):
        sixCAVG += s[1]
        sixMrkAvg += s[2]
        sixC += 1
        if(s[1] > HighTimeSix):
            HighTimeSix = s[1]
        if(lowCheck6 == 0):
            lowCheck6 +=1;
            LowTimeSix = s[1]
        if(s[1] < LowTimeSix):
            LowTimeSix = s[1]
        if(s[2] > HighMarkSix):
            HighMarkSix = s[2]
        if(low6 == 0):
            low6 +=1;
            LowMarkSix = s[2]
        if(s[2] < LowMarkSix):
            LowMarkSix = s[2]
    elif(s[0] == 7):
        sevenCAVG += s[1]
        sevenMrkAvg += s[2]
        sevenC += 1
        if(s[1] > HighTimeSeven):
            HighTimeSeven = s[1]
        if(lowCheck7 == 0):
            lowCheck7 +=1;
            LowTimeSeven = s[1]
        if(s[1] < LowTimeSeven):
            LowTimeSeven = s[1]
        if(s[2] > HighMarkSeven):
            HighMarkSeven = s[2]
        if(low7 == 0):
            low7 +=1
            LowMarkSeven = s[2]
        if(s[2] < LowMarkSeven):
            LowMarkSeven = s[2]
    elif(s[0] == 8):
        eightCAVG += s[1]
        eightMrkAvg += s[2]
        eightC += 1
        if(s[1] > HighTimeEight):
            HighTimeEight = s[1]
        if(lowCheck8 == 0):
            lowCheck8 +=1;
            LowTimeEight = s[1]
        if(s[1] < LowTimeEight):
            LowTimeEight = s[1]
        if(s[2] > HighMarkEight):
            HighMarkEight = s[2]
        if(low8 == 0):
            low8 +=1;
            LowMarkEight = s[2]
        if(s[2] < LowMarkEight):
            LowMarkEight = s[2]

# the average amount of time spent studying by number of courses (number) DONE 
threeTIME = threeCAVG / threeC
print("Avg time studying for 3 courses:", threeTIME)
fourTIME = fourCAVG / fourC
print("Avg time studying for 4 courses:", fourTIME)
fiveTIME = fiveCAVG / fiveC
print("Avg time studying for 5 courses:", fiveTIME)
sixTIME = sixCAVG / sixC
print("Avg time studying for 6 courses:", sixTIME)
sevenTIME = sevenCAVG / sevenC
print("Avg time studying for 7 courses:", sevenTIME)
eightTIME = eightCAVG / eightC
print("Avg time studying for 8 courses:", eightTIME)

# the average mark by number of courses (number)
# threeMrkAvg, fourMrkAvg, fiveMrkAvg, sixMrkAvg, sevenMrkAvg, eightMrkAvg
# AVGthree, AVGFour, AVGFive, AVGSix, AVGSeven, AVGeight 
AVGthree = threeMrkAvg / threeC
print("Avg marks for 3 courses:", AVGthree)
AVGFour = fourMrkAvg / fourC
print("Avg marks for 4 courses:", AVGFour)
AVGFive = fiveMrkAvg / fiveC
print("Avg marks for 5 courses:", AVGFive)
AVGSix = sixMrkAvg / sixC
print("Avg marks for 6 courses:", AVGSix)
AVGSeven = sevenMrkAvg / sevenC
print("Avg marks for 7 courses:", AVGSeven)
AVGeight = eightMrkAvg / eightC
print("Avg marks for 8 courses:", AVGeight)

# the highest amount of time spend studying by number of courses (number)
# the lowest amount of time spend studying by number of courses (number)
# HighTimeThree, HighTimeFour, HighTimeFive, HighTimeSix, HighTimeSeven, HighTimeEight
# LowTimeThree, LowTimeFour, LowTimeFive, LowTimeSix, LowTimeSeven, LowTimeEight 
print("Highest & Lowest amount of time for for 3 courses: highest: ", HighTimeThree, " Lowest: ", LowTimeThree)
print("Highest & Lowest amount of time for for 4 courses: highest: ", HighTimeFour, " Lowest: ", LowTimeFour)
print("Highest & Lowest amount of time for for 5 courses: highest: ", HighTimeFive, " Lowest: ", LowTimeFive)
print("Highest & Lowest amount of time for for 6 courses: highest: ", HighTimeSix, " Lowest: ", LowTimeSix)
print("Highest & Lowest amount of time for for 7 courses: highest: ", HighTimeSeven, " Lowest: ", LowTimeSeven)
print("Highest & Lowest amount of time for for 8 courses: highest: ", HighTimeEight, " Lowest: ", LowTimeEight)

# the highest grade by number of courses (number)
# the lowest grade by number of courses (number)
# HighMarkThree, HighMarkFour, HighMarkFive, HighMarkSix, HighMarkSeven, HighMarkEight 
# LowMarkThree, LowMarkFour, LowMarkFive, LowMarkSix, LowMarkSeven, LowMarkEight
print("Highest & Lowest grade for for 3 courses: highest: ", HighMarkThree, " Lowest: ", LowMarkThree)
print("Highest & Lowest grade for for 4 courses: highest: ", HighMarkFour, " Lowest: ", LowMarkFour)
print("Highest & Lowest grade for for 5 courses: highest: ", HighMarkFive, " Lowest: ", LowMarkFive)
print("Highest & Lowest grade for for 6 courses: highest: ", HighMarkSix, " Lowest: ", LowMarkSix)
print("Highest & Lowest grade for for 7 courses: highest: ", HighMarkSeven, " Lowest: ", LowMarkSeven)
print("Highest & Lowest grade for for 8 courses: highest: ", HighMarkEight, " Lowest: ", LowMarkEight)


# Produce at least 3 graphs that visually illustrate relationships in the data.  

#number of courses vs. average time studying per course
x = [3,4,5,6,7,8] #number of courses
y = [threeTIME,fourTIME,fiveTIME,sixTIME, sevenTIME, eightTIME] # average time studying

plt.bar(x,y)
plt.show()

#number of courses vs. average marks per course
w = [3,4,5,6,7,8] #number of courses
z = [AVGthree,AVGFour,AVGFive,AVGSix,AVGSeven,AVGeight] # average marks 

plt.bar(w,z)
plt.show()

#number of courses vs.highest marks per courses
q = [3,4,5,6,7,8] #number of courses
r = [HighMarkThree, HighMarkFour, HighMarkFive, HighMarkSix, HighMarkSeven, HighMarkEight] # average marks 

plt.bar(q,r)
plt.show()
# Out:
# [[3.0, 4.508, 19.202], [4.0, 0.096, 7.734], [4.0, 3.133, 13.811], [6.0, 7.909, 53.018], [8.0, 7.811, 55.299], [6.0, 3.211, 17.822], [3.0, 6.063, 29.889], [5.0, 3.413, 17.264], [4.0, 4.41, 20.348], [3.0, 6.173, 30.862], [3.0, 7.353, 42.036], [7.0, 0.423, 12.132], [7.0, 4.218, 24.318], [3.0, 4.274, 17.672], [3.0, 2.908, 11.397], [4.0, 4.26, 19.466], [5.0, 5.719, 30.548], [8.0, 6.08, 38.49], [6.0, 7.711, 50.986], [8.0, 3.977, 25.133], [4.0, 4.733, 22.073], [6.0, 6.126, 35.939], [5.0, 2.051, 12.209], [7.0, 4.875, 28.043], [4.0, 3.635, 16.517], [3.0, 1.407, 6.623], [7.0, 0.508, 12.647], [8.0, 4.378, 26.532], [5.0, 0.156, 9.333], [4.0, 1.299, 8.837], [8.0, 3.864, 24.172], [3.0, 1.923, 8.1], [8.0, 0.932, 15.038], [6.0, 6.594, 39.965], [3.0, 4.083, 17.171], [3.0, 7.543, 43.978], [4.0, 2.966, 13.119], [6.0, 7.283, 46.453], [7.0, 6.533, 41.358], [6.0, 7.775, 51.142], [4.0, 0.14, 7.336], [6.0, 2.754, 15.725], [6.0, 3.591, 19.771], [5.0, 1.557, 10.429], [4.0, 1.954, 9.742], [3.0, 2.061, 8.924], 
# ...
